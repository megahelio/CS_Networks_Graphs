# %%
from atproto import Client, models
import os
import sys
import csv
import datetime
import time
from tqdm.notebook import tqdm, trange

# %%
# --- PARAMETERS ---

# Maximum posts to retrieve per keyword
MAX_POSTS_PER_KEYWORD = 100

# %%
OUTPUT_DIR = "./downloaded_data/"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
# Date Range Filter (Y-M-D)
# Only posts created within this range will be saved.
DATE_FILTER_START = "2019-01-01"
DATE_FILTER_END = "2026-01-01" # Set to a future date to include everything up to now

# %%
# Authenticated Bluesky Client Credentials
HANDLE = os.getenv("BLUESKY_HANDLE", "yourhandle.bsky.social")
PASSWORD = os.getenv("BLUESKY_PASSWORD", "your-app-password")

# %%
# Keyword Groups by "Country"/Language
# Each group creates a separate dataset.
KEYWORD_GROUPS = {
    "Global": { # English
        "lang": "en",
        "keywords": [
            "green transition", "greenhouse effect", "biodiversity", "extreme weather events",
            "co2", "emissions", "global warming", "glaciers", "renewable energy",
            "fake news", "catastrophe", "anthropic", "sustainable biofuels",
            "desertification", "deforestation", "clean energy",
            "sea level rise", "extinction"
        ]
    },
    "Spain": { # Spanish
        "lang": "es",
        "keywords": [
            "transición ecológica", "efecto invernadero", "biodiversidad", "eventos climáticos extremos",
            "co2", "emisiones", "calentamiento global", "glaciares", "energía renovable",
            "noticias falsas", "catástrofe", "antrópico", "biocombustibles sostenibles",
            "desertificación", "deforestación", "energía limpia",
            "aumento del nivel del mar", "extinción"
        ]
    },
    "Portugal": { # Portuguese
        "lang": "pt",
        "keywords": [
            "transição verde", "efeito estufa", "biodiversidade", "eventos climáticos extremos",
            "co2", "emissões", "aquecimento global", "geleiras", "energia renovável",
            "fake news", "catástrofe", "antrópico", "biocombustíveis sustentáveis",
            "desertificação", "desmatamento", "energia limpa",
            "aumento do nível do mar", "extinção"
        ]
    },
    "Italy": { # Italian
        "lang": "it",
        "keywords": [
            "transizione verde", "effetto serra", "biodiversità", "eventi meteorologici estremi",
            "co2", "emissioni", "riscaldamento globale", "ghiacciai", "energia rinnovabile",
            "fake news", "catastrofe", "antropico", "biocarburanti sostenibili",
            "desertificazione", "deforestazione", "energia pulita",
            "innalzamento del livello del mare", "estinzione"
        ]
    },
    "Germany": { # German
        "lang": "de",
        "keywords": [
            "grüne Wende", "Treibhauseffekt", "Biodiversität", "Wetterextreme",
            "co2", "Emissionen", "Erderwärmung", "Gletscher", "erneuerbare Energien",
            "Fake News", "Katastrophe", "anthropogen", "nachhaltige Biokraftstoffe",
            "Wüstenbildung", "Abholzung", "saubere Energie",
            "Meeresspiegelanstieg", "Aussterben"
        ]
    }
}

# %%
def download_posts_by_keywords(keywords: list[str], handle: str, password: str, max_posts: int = 100, lang: str = None, start_date: str = None, end_date: str = None):
    """
    Downloads posts from Bluesky based on a list of keywords.
    Applies client-side date filtering if start_date/end_date provided (ISO strings YYYY-MM-DD).
    """
    client = Client()
    try:
        client.login(handle, password)
    except Exception as e:
        print(f"Failed to login: {e}")
        return []

    all_found_posts = []
    
    # Iterate through keywords with a progress bar
    # Use leave=False so it clears after completion if desired, or True to keep it.
    for keyword in tqdm(keywords, desc=f"Keywords ({lang})", leave=False):
        posts_for_keyword = []
        cursor = None
        
        # Loop until we have enough *valid* posts
        # Safety break to prevent infinite loops
        request_count = 0
        MAX_REQUESTS = 20 

        # Inner progress bar for posts collection
        with tqdm(total=max_posts, desc=f"Downloading '{keyword}'", leave=False) as post_pbar:
            
            while len(posts_for_keyword) < max_posts and request_count < MAX_REQUESTS:
                request_count += 1
                try:
                    # Calculate limit request
                    remaining = max_posts - len(posts_for_keyword)
                    # Always ask for more to filter by date efficiently, capped at 100
                    batch_limit = 100
                    
                    params = models.AppBskyFeedSearchPosts.Params(
                        q=keyword,
                        limit=batch_limit,
                        cursor=cursor,
                        lang=lang
                    )
                    
                    response = client.app.bsky.feed.search_posts(params)

                    if response and response.posts:
                        new_valid_posts = 0
                        for post in response.posts:
                            # Check Date Filter
                            created_at = post.record.created_at
                            if start_date and created_at < start_date:
                                continue
                            if end_date and created_at > end_date:
                                continue
                                
                            # Construct URL
                            rkey = post.uri.split('/')[-1]
                            web_url = f"https://bsky.app/profile/{post.author.handle}/post/{rkey}"
                            
                            post_data = {
                                'url': web_url,
                                'author_handle': post.author.handle,
                                'text': post.record.text,
                                'created_at': created_at,
                                'like_count': post.like_count,
                                'repost_count': post.repost_count,
                                'reply_count': post.reply_count,
                                'lang': lang,
                                'keyword': keyword
                            }
                            
                            # Add if we haven't hit the limit yet
                            if len(posts_for_keyword) < max_posts:
                                 posts_for_keyword.append(post_data)
                                 new_valid_posts += 1
                                 post_pbar.update(1)
                            else:
                                break
                        
                        # Update cursor for next page
                        if hasattr(response, 'cursor') and response.cursor and len(posts_for_keyword) < max_posts:
                            cursor = response.cursor
                        else:
                            break 
                    else:
                        break # No posts found
                    
                    time.sleep(0.5)
                    
                except Exception as e:
                    print(f"Error searching for '{keyword}': {e}")
                    break
        
        all_found_posts.extend(posts_for_keyword)

    return all_found_posts

# %%
def save_posts_to_csv(posts, filename):
    """
    Saves a list of dictionaries to a CSV file.
    Replaces double quotes with single quotes in all string values.
    """
    if not posts:
        print(f"No posts to save for {filename}.")
        return

    fieldnames = list(posts[0].keys())
    
    sanitized_posts = []
    for post in posts:
        sanitized_post = {}
        for key, value in post.items():
            if isinstance(value, str):
                sanitized_post[key] = value.replace('"', "'")
            else:
                sanitized_post[key] = value
        sanitized_posts.append(sanitized_post)

    try:
        with open(filename, mode='w', newline='', encoding='utf-8') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            writer.writeheader()
            writer.writerows(sanitized_posts)
        print(f"Successfully saved {len(posts)} posts to '{filename}'")
    except IOError as e:
        print(f"Error saving to CSV: {e}")

# %%
# Execution
if __name__ == '__main__':
    if "yourhandle" in HANDLE or "your-app-password" in PASSWORD:
        print("WARNING: It looks like you are using placeholder credentials.")
        print("Please update the 'parameters' cell above with your actual Handle and Password.")
    else:
        print(f"Starting multi-language download loop...")
        print(f"Max posts per keyword: {MAX_POSTS_PER_KEYWORD}")
        print(f"Date Range: {DATE_FILTER_START} to {DATE_FILTER_END}")
        
        # Top level progress bar for separate datasets/languages
        # We use tqdm on KEYWORD_GROUPS.items()
        for group_name, config in tqdm(KEYWORD_GROUPS.items(), desc="Processing Datasets"):
            target_lang = config['lang']
            keywords = config['keywords']
            
            # print(f"Processing Group: {group_name}")
            
            posts = download_posts_by_keywords(
                keywords, 
                HANDLE, 
                PASSWORD, 
                max_posts=MAX_POSTS_PER_KEYWORD, 
                lang=target_lang,
                start_date=DATE_FILTER_START,
                end_date=DATE_FILTER_END
            )
            

            output_filename = f"{OUTPUT_DIR}{group_name}_bluesky_posts.csv"
            save_posts_to_csv(posts, output_filename)
# Out:
# Starting multi-language download loop...
# Max posts per keyword: 100
# Date Range: 2019-01-01 to 2026-01-01
# Processing Datasets:   0%|          | 0/5 [00:00<?, ?it/s]
# Keywords (en):   0%|          | 0/18 [00:00<?, ?it/s]
# Downloading 'green transition':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'greenhouse effect':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'biodiversity':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'extreme weather events':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'co2':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'emissions':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'global warming':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'glaciers':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'renewable energy':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'fake news':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'catastrophe':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'anthropic':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'sustainable biofuels':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'desertification':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'deforestation':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'clean energy':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'sea level rise':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'extinction':   0%|          | 0/100 [00:00<?, ?it/s]
# Successfully saved 1800 posts to './downloaded_data/Global_bluesky_posts.csv'
# Keywords (es):   0%|          | 0/18 [00:00<?, ?it/s]
# Downloading 'transición ecológica':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'efecto invernadero':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'biodiversidad':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'eventos climáticos extremos':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'co2':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'emisiones':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'calentamiento global':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'glaciares':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'energía renovable':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'noticias falsas':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'catástrofe':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'antrópico':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'biocombustibles sostenibles':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'desertificación':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'deforestación':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'energía limpia':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'aumento del nivel del mar':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'extinción':   0%|          | 0/100 [00:00<?, ?it/s]
# Successfully saved 1657 posts to './downloaded_data/Spain_bluesky_posts.csv'
# Keywords (pt):   0%|          | 0/18 [00:00<?, ?it/s]
# Downloading 'transição verde':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'efeito estufa':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'biodiversidade':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'eventos climáticos extremos':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'co2':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'emissões':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'aquecimento global':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'geleiras':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'energia renovável':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'fake news':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'catástrofe':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'antrópico':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'biocombustíveis sustentáveis':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'desertificação':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'desmatamento':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'energia limpa':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'aumento do nível do mar':   0%|          | 0/100 [00:00<?, ?it/s]
# Downloading 'extinção':   0%|          | 0/100 [00:00<?, ?it/s]
# Successfully saved 1644 posts to './downloaded_data/Portugal_bluesky_posts.csv'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 19
#      15 keywords = config['keywords']
#      17 # print(f"Processing Group: {group_name}")
# ---> 19 posts = download_posts_by_keywords(
#      20     keywords,
#      21     HANDLE,
#      22     PASSWORD,
#      23     max_posts=MAX_POSTS_PER_KEYWORD,
#      24     lang=target_lang,
#      25     start_date=DATE_FILTER_START,
#      26     end_date=DATE_FILTER_END
#      27 )
#      30 output_filename = f"{OUTPUT_DIR}{group_name}_bluesky_posts.csv"
#      31 save_posts_to_csv(posts, output_filename)
#
# Cell In[7], line 6, in download_posts_by_keywords(keywords, handle, password, max_posts, lang, start_date, end_date)
#       1 def download_posts_by_keywords(keywords: list[str], handle: str, password: str, max_posts: int = 100, lang: str = None, start_date: str = None, end_date: str = None):
#       2     """
#       3     Downloads posts from Bluesky based on a list of keywords.
#       4     Applies client-side date filtering if start_date/end_date provided (ISO strings YYYY-MM-DD).
#       5     """
# ----> 6     client = Client()
#       7     try:
#       8         client.login(handle, password)
#
# File y:\git\Networks_CS\.venv\Lib\site-packages\atproto_client\client\client.py:25, in Client.__init__(self, base_url, *args, **kwargs)
#      24 def __init__(self, base_url: t.Optional[str] = None, *args: t.Any, **kwargs: t.Any) -> None:
# ---> 25     super().__init__(base_url, *args, **kwargs)
#      27     self._refresh_lock = Lock()
#      29     self.me: t.Optional['models.AppBskyActorDefs.ProfileViewDetailed'] = None
#
# File y:\git\Networks_CS\.venv\Lib\site-packages\atproto_client\client\methods_mixin\session.py:94, in SessionMethodsMixin.__init__(self, *args, **kwargs)
#      93 def __init__(self, *args: t.Any, **kwargs: t.Any) -> None:
# ---> 94     super().__init__(*args, **kwargs)
#      95     self._session: t.Optional[Session] = None
#      96     self._session_dispatcher = SessionDispatcher()
#
# File y:\git\Networks_CS\.venv\Lib\site-packages\atproto_client\client\raw.py:18, in ClientRaw.__init__(self, *args, **kwargs)
#      17 def __init__(self, *args: t.Any, **kwargs: t.Any) -> None:
# ---> 18     super().__init__(*args, **kwargs)
#      20     self.com = sync_ns.ComNamespace(self)
#      21     self.app = sync_ns.AppNamespace(self)
#
# File y:\git\Networks_CS\.venv\Lib\site-packages\atproto_client\client\base.py:92, in ClientBase.__init__(self, base_url, request)
#      90 def __init__(self, base_url: t.Optional[str] = None, request: t.Optional[Request] = None) -> None:
#      91     if request is None:
# ---> 92         request = Request()
#      94     self._request = request
#      95     self._base_url = _handle_base_url(base_url)
#
# File y:\git\Networks_CS\.venv\Lib\site-packages\atproto_client\request.py:197, in Request.__init__(self, **kwargs)
#     195 def __init__(self, **kwargs: t.Any) -> None:
#     196     super().__init__()
# --> 197     self._client = httpx.Client(follow_redirects=True, **kwargs)
#
# File y:\git\Networks_CS\.venv\Lib\site-packages\httpx\_client.py:688, in Client.__init__(self, auth, params, headers, cookies, verify, cert, trust_env, http1, http2, proxy, mounts, timeout, follow_redirects, limits, max_redirects, event_hooks, base_url, transport, default_encoding)
#     685 allow_env_proxies = trust_env and transport is None
#     686 proxy_map = self._get_proxy_map(proxy, allow_env_proxies)
# --> 688 self._transport = self._init_transport(
#     689     verify=verify,
#     690     cert=cert,
#     691     trust_env=trust_env,
#     692     http1=http1,
#     693     http2=http2,
#     694     limits=limits,
#     695     transport=transport,
#     696 )
#     697 self._mounts: dict[URLPattern, BaseTransport | None] = {
#     698     URLPattern(key): None
#     699     if proxy is None
#    (...)    709     for key, proxy in proxy_map.items()
#     710 }
#     711 if mounts is not None:
#
# File y:\git\Networks_CS\.venv\Lib\site-packages\httpx\_client.py:731, in Client._init_transport(self, verify, cert, trust_env, http1, http2, limits, transport)
#     728 if transport is not None:
#     729     return transport
# --> 731 return HTTPTransport(
#     732     verify=verify,
#     733     cert=cert,
#     734     trust_env=trust_env,
#     735     http1=http1,
#     736     http2=http2,
#     737     limits=limits,
#     738 )
#
# File y:\git\Networks_CS\.venv\Lib\site-packages\httpx\_transports\default.py:153, in HTTPTransport.__init__(self, verify, cert, trust_env, http1, http2, limits, proxy, uds, local_address, retries, socket_options)
#     150 import httpcore
#     152 proxy = Proxy(url=proxy) if isinstance(proxy, (str, URL)) else proxy
# --> 153 ssl_context = create_ssl_context(verify=verify, cert=cert, trust_env=trust_env)
#     155 if proxy is None:
#     156     self._pool = httpcore.ConnectionPool(
#     157         ssl_context=ssl_context,
#     158         max_connections=limits.max_connections,
#    (...)    166         socket_options=socket_options,
#     167     )
#
# File y:\git\Networks_CS\.venv\Lib\site-packages\httpx\_config.py:40, in create_ssl_context(verify, cert, trust_env)
#      37         ctx = ssl.create_default_context(capath=os.environ["SSL_CERT_DIR"])
#      38     else:
#      39         # Default case...
# ---> 40         ctx = ssl.create_default_context(cafile=certifi.where())
#      41 elif verify is False:
#      42     ctx = ssl.SSLContext(ssl.PROTOCOL_TLS_CLIENT)
#
# File C:\Python313\Lib\ssl.py:717, in create_default_context(purpose, cafile, capath, cadata)
#     713 context.verify_flags |= (_ssl.VERIFY_X509_PARTIAL_CHAIN |
#     714                          _ssl.VERIFY_X509_STRICT)
#     716 if cafile or capath or cadata:
# --> 717     context.load_verify_locations(cafile, capath, cadata)
#     718 elif context.verify_mode != CERT_NONE:
#     719     # no explicit cafile, capath or cadata but the verify mode is
#     720     # CERT_OPTIONAL or CERT_REQUIRED. Let's try to load default system
#     721     # root CA certificates for the given purpose. This may fail silently.
#     722     context.load_default_certs(purpose)
#
# KeyboardInterrupt:
